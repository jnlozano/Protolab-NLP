# %%
import nltk
import csv
import numpy as np 
import pandas as pd
from nltk.corpus import stopwords
from gensim import models
import numpy as np
import gensim
#nltk.download()
#this will open a GUI from which you can download the corpus

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer() 
tokenizer = nltk.RegexpTokenizer(r"\w+") #removes punctuation 

def nltk_tokenizer(sent):
    
    sent = sent.lower() 
    word_tokens = tokenizer.tokenize(sent)
  
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
    end = []
    
    for x in filtered_sentence:
        n = lemmatizer.lemmatize(x)
        end.append(n)
    #return(word_tokens) 
    return(end)

# %%
#Seperate specific comment thread into their seperate comments.

allc = []
with open('idea_comment_clear_halfed.csv', encoding = 'utf8') as csvfile: 
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        allc.append(row[3])
print('Length of Comments:' + str(len(allc))) # half of all the comments
# Out:
# Length of Comments:7508

# %%
i = 0 
while i < len(allc):
     allc[i] = nltk_tokenizer(allc[i]) 
     i += 1

# %%
import gensim.downloader as api
from gensim.models import TfidfModel
from gensim.corpora import Dictionary

dct = Dictionary(allc)
corpus = [dct.doc2bow(line) for line in allc]
model = TfidfModel(corpus)  # fit model
vector = model[corpus[0]]

# %%
from gensim import models
from gensim import corpora
from gensim.utils import simple_preprocess
#For now, it is doing individual lines 
mydict = corpora.Dictionary([simple_preprocess(line) for line in allc[1]])
corpus = [mydict.doc2bow(simple_preprocess(line)) for line in allc[1]]
#for doc in corpus:
    #print([[mydict[id], freq] for id, freq in doc])

# %%
#this is just for the first comment

tfidf = models.TfidfModel(corpus, smartirs='ntc')
for doc in tfidf[corpus]:
    print([[mydict[id], np.around(freq, decimals=2)] for id, freq in doc])
# Out:
# [['brought', 1.0]]
# [['back', 1.0]]
# [['june', 1.0]]
# []
# [['included', 1.0]]
# [['graphic', 1.0]]
# [['help', 1.0]]
# [['people', 1.0]]
# [['visual', 1.0]]
# [['issue', 1.0]]
# [['going', 1.0]]
# [['copy', 1.0]]
# [['entire', 1.0]]
# [['comment', 1.0]]
# [['currently', 1.0]]
# [['search', 1.0]]
# [['option', 1.0]]
# [['associate', 1.0]]
# [['blueprint', 1.0]]
# [['seem', 1.0]]
# [['search', 1.0]]
# [['within', 1.0]]
# [['sub', 1.0]]
# [['account', 1.0]]
# [['nothing', 1.0]]
# [['outside', 1.0]]
# [['even', 1.0]]
# [['sub', 1.0]]
# [['account', 1.0]]
# [['look', 1.0]]
# [['sub', 1.0]]
# [['account', 1.0]]
# [['within', 1.0]]
# [['well', 1.0]]
# [['sub', 1.0]]
# [['account', 1.0]]
# [['even', 1.0]]
# [['admin', 1.0]]
# [['cannot', 1.0]]
# [['assign', 1.0]]
# [['blueprint', 1.0]]
# [['course', 1.0]]
# [['within', 1.0]]
# [['sub', 1.0]]
# [['account', 1.0]]
# [['blueprint', 1.0]]
# [['organization', 1.0]]
# [['ease', 1.0]]
# [['finding', 1.0]]
# [['cannot', 1.0]]
# ...

# %%
#This creates a bag of words for all of the comments in a clean manner. no punctuation, lemmatized, no stop words, etc 
def listToString(s):  
    
    # initialize an empty string 
    str1 = "" 
    # traverse in the string   
    for ele in s: 
        str1 += ele   
        str1 += ' '
       
    return str1 

cleanc = allc
i = 0 
while i < len(cleanc):
    cleanc[i] = listToString(cleanc[i])
    i+=1
i = 0 

char2remove = "Â"
i=0
while i < len(cleanc):
    for character in char2remove:
        cleanc[i] = cleanc[i].replace(character, "")
    i+= 1

# %%
mydict = corpora.Dictionary([simple_preprocess(line) for line in cleanc])
corpus = [mydict.doc2bow(simple_preprocess(line)) for line in cleanc]

#for doc in corpus:
#    print([[mydict[id], freq] for id, freq in doc])

tfidf = models.TfidfModel(corpus, smartirs='ntc')
for doc in tfidf[corpus]:
    print([[mydict[id], np.around(freq, decimals=2)] for id, freq in doc])
# Out:
# [['comment', 1.0]]
# [['comment', 0.03], ['account', 0.38], ['admin', 0.05], ['assign', 0.06], ['associate', 0.09], ['back', 0.04], ['better', 0.04], ['blueprint', 0.46], ['brought', 0.07], ['cannot', 0.16], ['class', 0.07], ['contain', 0.08], ['copy', 0.05], ['course', 0.06], ['currently', 0.04], ['diagram', 0.1], ['ease', 0.08], ['either', 0.05], ['english', 0.43], ['entire', 0.06], ['even', 0.07], ['explain', 0.07], ['finding', 0.07], ['going', 0.04], ['graphic', 0.08], ['help', 0.03], ['hopefully', 0.06], ['included', 0.06], ['issue', 0.04], ['june', 0.07], ['leave', 0.06], ['level', 0.05], ['live', 0.19], ['look', 0.04], ['main', 0.07], ['nothing', 0.06], ['option', 0.03], ['organization', 0.07], ['outside', 0.06], ['people', 0.04], ['root', 0.08], ['search', 0.1], ['section', 0.04], ['seem', 0.06], ['separate', 0.05], ['start', 0.05], ['sub', 0.45], ['thing', 0.04], ['unless', 0.06], ['visual', 0.07], ['wanted', 0.05], ['well', 0.04], ['within', 0.12]]
# ...

# %%
#pre-processing further based on gensim tutorial -- best used with all comments

from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
for idx in range(len(cleanc)):
    cleanc[idx] = tokenizer.tokenize(cleanc[idx])
    
# Remove numbers, but not words that contain numbers. 
docs = [[token for token in doc if not token.isnumeric()] for doc in cleanc]

# Remove words that are only one character.
docs = [[token for token in doc if len(token) > 1 and token != 'i'] for doc in cleanc] #Maybe not filter 'I'

#create dictionary that shows words that are filtered out
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-4367fe8f14c0> in <module>()
#       4 tokenizer = RegexpTokenizer(r'\w+')
#       5 for idx in range(len(cleanc)):
# ----> 6     cleanc[idx] = tokenizer.tokenize(cleanc[idx])
#       7
#       8 # Remove numbers, but not words that contain numbers.
#
# ~\Anaconda3\envs\GloVe\lib\site-packages\nltk\tokenize\regexp.py in tokenize(self, text)
#     129         # If our regexp matches tokens, use re.findall:
#     130         else:
# --> 131             return self._regexp.findall(text)
#     132
#     133     def span_tokenize(self, text):
#
# TypeError: expected string or bytes-like object

# %%
from gensim.corpora import Dictionary

# Create a dictionary representation of the documents.
dictionary = Dictionary(docs)

# Filter out words that occur less than 50 documents, or more than 70% of the documents. 7508 'docs' 
dictionary.filter_extremes(no_below=50  , no_above=0.7)

# %%
corpus = [dictionary.doc2bow(doc) for doc in docs]
#corpus

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 787
# Number of documents: 7508

# %%
from gensim.models import LdaModel

# Set training parameters. Unsure on parameters 
num_topics = 10
chunksize = 2000
passes = 20
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make a index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)

# %%
top_topics = model.top_topics(corpus) #, num_words=20)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# Average topic coherence: -2.2337.
# [([(0.15217139, 'idea'),
#    (0.08112908, 'change'),
#    (0.056014657, 'process'),
#    (0.052260138, 'feature'),
#    (0.048813596, 'stage'),
#    (0.039357856, 'voted'),
#    (0.03388191, 'radar'),
#    (0.033120543, 'sort'),
#    (0.028256506, 'voting'),
#    (0.02226656, 'open'),
#    (0.021592764, 'one'),
#    (0.020761825, 'product'),
#    (0.019206533, 'making'),
#    (0.019131562, 'blog'),
#    (0.018971777, 'activity'),
#    (0.018193748, 'top'),
#    (0.018140705, 'list'),
#    (0.017751493, 'considered'),
#    (0.017692868, 'post'),
#    (0.017364793, 'see')],
#   -1.410615690261066),
#  ([(0.034102213, 'canvas'),
#    (0.020628015, 'point'),
#    (0.015893685, 'one'),
#    (0.014537624, 'get'),
#    (0.014312397, 'time'),
#    (0.01248008, 'year'),
#    (0.012414383, 'make'),
#    (0.01226282, 'thing'),
#    (0.011853351, 'need'),
#    (0.011599697, 'way'),
#    (0.0109222215, 'like'),
#    (0.009848555, 'use'),
# ...

# %%
model.print_topics(50)

#lsi, latent semantic indexing -- look at 
#text summarization on larger docs 

#look at idea level. lda on idea column 
#pull comments that came from each topic! 
#seeded lda 
#apply similiar analysis to Twitter data on COVID19 
#subset tweets that only include covid/coronavirus --> words associated with covid like qurantine, hospital, flu, etc 
#seeded LDA with covid/coronavirus and find which words are related
# Out:
# [(0,
#   '0.094*"student" + 0.044*"assignment" + 0.040*"grade" + 0.028*"comment" + 0.027*"submission" + 0.023*"would" + 0.020*"see" + 0.016*"instructor" + 0.015*"feedback" + 0.013*"grading"'),
#  (1,
#   '0.034*"canvas" + 0.021*"point" + 0.016*"one" + 0.015*"get" + 0.014*"time" + 0.012*"year" + 0.012*"make" + 0.012*"thing" + 0.012*"need" + 0.012*"way"'),
#  (2,
#   '0.152*"idea" + 0.081*"change" + 0.056*"process" + 0.052*"feature" + 0.049*"stage" + 0.039*"voted" + 0.034*"radar" + 0.033*"sort" + 0.028*"voting" + 0.022*"open"'),
#  (3,
#   '0.091*"idea" + 0.048*"feature" + 0.033*"vote" + 0.022*"canvas" + 0.018*"thanks" + 0.018*"voting" + 0.015*"please" + 0.015*"community" + 0.014*"request" + 0.014*"archived"'),
#  (4,
#   '0.056*"quiz" + 0.052*"question" + 0.025*"canvas" + 0.018*"tool" + 0.017*"file" + 0.015*"answer" + 0.013*"content" + 0.013*"option" + 0.012*"would" + 0.012*"google"'),
#  (5,
# ...
